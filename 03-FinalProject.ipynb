# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Abstract
#
# Do you ever wonder if the type of music you listen to somehow have inherent relations to your current mood and if your age and gender group have correlations to why you decide to listen to what you really listen to? Diving into this question and to figure out if there is a statistically significant association between someone's primary motivation to listening to music with their age/gender groups, our team utilized a Spotify Kaggle dataset of survey responses to figure this out.
#
#
#
# After data wrangling, we decided to exclude a user group of those under 12 years old after discovering Spotify's user age policy. We also merged age brackets and use one-hot encoding to select mood columns to preserve the independence of observations. Afterwards we conducted a chi square test of independence to run separate tests of the different motivations from our dataset with our chosen categories of age and gender.
#
#
#
# Our analysis showed that age is significantly associated with our relaxation & stress relief as well as our uplifting & motivational listening motivation where our p-value < 0.001. Whereas sadness and social listening was not found to be statistically significant. Young adults (20-35 years old) was found to have motivations to listen to relaxation and stress relief more so than other groups. As for our analysis of motivation with gender, it appears that throughout, all the motivations were statistically significant as the p-value for all were <0.05 and we found that women show higher association with relaxation & stress relief whereas on the opposite spectrum, men show the lowest association with uplifting & motivational motivations, but it may also be notable to mention that the social gatherings/parties motivator for gender's p-value is 0.0454 which for this class, we are not super confident of trusting.
#
#
#
# Overall, our hypothesis can be supported by our evidence as it appears that age does have some influence in our motivations our music taste like for stress relief and uplifting types of music. We believe that while age and gender do influence certain aspects of motivations for why people listen to music, those 2 groups themselves cannot fully explain why people listen to music as there are possibilities of different confounds.

# %% [markdown]
# ## Authors
#
# - Taiyo Morita: Project Administration, Review, project proposal
# - Christina Lin: Data, Revision, project proposal
# - Amberly Truong: Data, Writing, project proposal
# - Rohan Chidurala: Data, Revision
# - Shazi Bidarian: Data, Revision

# %% [markdown]
# # Research Question

# %% [markdown]
#  - Is there a statistically significant association between an individual's demographic profile (specifically, age group and gender) and their primary motivation for listening to music (e.g., relaxation, social gathering, sadness)?
#
# We set the feature of ages and genders as independent variables, and music-listening motivation as a dependent variable. To determine if a relationship exists, we will approach this as a statistical inference task. Since our dependent and independent variables are all categorical, we plan to use Chi-square tests of independence.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
#  - Music functions in individuals’ daily lives as more than mere entertainment; it serves as an important tool for emotion regulation, the formation of self-identity, and the development of social connections. The reasons why people listen to music vary widely, including relaxation, alleviating loneliness, and gaining energy. Understanding how these motivations differ according to demographic attributes such as age and gender is an important issue in music psychology. This study aims to determine, using  statistical methods, whether specific age groups or genders have statistically significant associations with primary motivations for listening to music.
#
#  - Previous research has shown that gender is a powerful factor influencing musical preferences and listening behavior. Colley (2008) reported that genre preferences among younger populations are closely tied to sex and gender-related personality traits. <a name="back1"> </a>[1](#ref1) In addition, age-related changes are an undeniable factor in musical engagement. A cross-sectional study by Vieillard & Gilet (2013) emphasized that older adults, compared to younger populations, are less likely to perceive negative emotions such as sadness or fear from music, highlighting that aging is associated with a relative preference for positive over negative emotions. <a name="back2"> </a>[2](#ref2) Recent industry data further suggests that for specific demographics, such as adult women, music increasingly serves a medicinal role in coping with life challenges. <a name="back4"> </a>[4](#ref4)
#
#  - In this project, we set age and gender as independent variables and music listening motivation as the dependent variable. Given that these are categorical data, we will employ the Pearson’s Chi-square test of independence. As established by McHugh (2013), the Chi-square test is the most appropriate non-parametric tool for evaluating whether a statistically significant association exists between nominal variables, providing the necessary robustness for frequency-based demographic data.<a name="back3"> </a>[3](#ref3)
#
# ### References
#
# <a name="ref1"> </a>[^](#back1) Colley, A. (2008) Young People's Musical Taste: Relationship With Gender and Gender-Related Traits. *Journal of Applied Social Psychology*. https://files.commons.gc.cuny.edu/wp-content/blogs.dir/3759/files/2018/05/Colley-2008-Journal_of_Applied_Social_Psychology.pdf
# <br>
#
# <a name="ref2"> </a>[^](#back2) Vieillard, S., & Gilet, A.-L. (2013) Age-related differences in affective responses to and memory for emotions conveyed by music: a cross-sectional study. *Frontiers in Psychology*. https://www.frontiersin.org/journals/psychology/articles/10.3389/fpsyg.2013.00711/full
# <br>
#
# <a name="ref3"> </a>[^](#back3) McHugh, M. L. (2013). The Chi-square test of independence. *Biochemia Medica*. https://pmc.ncbi.nlm.nih.gov/articles/PMC3900058/
# <br>
#
# <a name="ref4"> </a>[^](#back4) EdisonResearch. (2025) New Study: For U.S. Women Ages 18+, Music is Medicine. https://www.edisonresearch.com/new-study-for-u-s-women-ages-18-music-is-medicine/
# <br>
#
# <a name="ref5"> </a>[^](#back5) Rentfrow, P. J., & Gosling, S. D. (2003). The do re mi's of everyday life: The structure and personality correlates of music preferences. *Journal of Personality and Social Psychology*. https://gosling.psy.utexas.edu/wp-content/uploads/2014/09/JPSP03musicdimensions.pdf
# <br>
#
# <a name="ref6"> </a>[^](#back6) Bonneville-Roussy, A., Rentfrow, P. J., Xu, M. K., & Potter, J. (2013). Music through the ages: Trends in musical engagement and preferences from adolescence through middle adulthood. *Journal of Personality and Social Psychology*. https://pubmed.ncbi.nlm.nih.gov/23895269/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that music listening motivations will vary significantly across age and gender groups. Specifically we predict:
# - Adolescents (12-20): This group will primarily utilize music for social connection and emotional expression (sadness/relief). This prediction is supported by Rentfrow and Gosling (2003) <a name="back5"> </a>[5](#ref5), who found that younger populations utilize 'Reflective and Complex' music to process emotions and 'Upbeat' music for social gatherings.
# - Young Adults (20–35): We predict this group will demonstrate a transitional motivation, focusing on both social gatherings and relaxation/stress relief. This aligns with Bonneville-Roussy et al. (2013) <a name="back6"> </a>[6](#ref6), who noted that while social music use remains high in young adulthood, there is an emerging shift toward using music for self-regulation as individuals enter the workforce.
# - Established Adults and Seniors (35–60 and 60+): We hypothesize that these groups will primarily utilize music for relaxation and stress relief. According to Vieillard & Gilet (2013) [2](#ref2), aging is associated with a preference for positive emotional states and a reduction in music used for social identity, favoring music that serves as a tool for comfort and mood stability.
# - Gender (Women 20+): We predict that women within the adult age bins (20–35 and 35+) will show a statistically higher association with relaxation than their male counterparts. This is based on Edison Research (2025) [4](#ref4), which reported that 58% of women specifically identify music as a primary tool for stress relief and 'medicine' for coping with life challenges.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# 1. The ideal dataset for our question would have the mood and occasion separated, because the values in itself can be useful separated. The ideal age dataset would be separated by static differences such as by 10s instead of having an age bins varied from a difference of 6, 8, 15, etc.
#
# 2. Real Dataset
# https://www.kaggle.com/datasets/coulsonlll/spotify-user-behavior-survey-data
#
#  - This dataset is located in Kaggle, which is free to use and access. It is using data using user surveys regarding their Spotify usage. The variables we are thinking of using would be the 'Age', 'Gender', and 'music_Influencial_mood' column. The dataset contains a large quantity of participants (28,546 raw respondents).

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Dataset
#
#   - Dataset name: Spotify User Behavior Survey Data
#   - Link to the dataset: https://www.kaggle.com/datasets/coulsonlll/spotify-user-behavior-survey-data
#   - Number of observations: 28,546 in the raw file; 27,543 after excluding the "6–12" age group during cleaning
#   - Number of variables: 20 (raw); 6 retained after cleaning (Age, Gender, and four one-hot encoded mood columns)
#   - Description of the variables most relevant to this project
#
#     1. Age: A categorical variable indicating the respondent's age group, defining "12~20" as "Adolescents", "20~35" as "Young Adults", and both "35~60" and "60+" as "Established Adults and Seniors". This variable serves as an independent variable for Chi-square tests of independence.
#     2. Gender: A categorical variable representing the respondent's gender including "Female", "Male", and "Others". This is also utilized as an independent variable.
#     3. music_Influencial_mood: A categorical variable indicating the primary motivation or mood for listening to music including 4 categories: "Relaxation and stress relief", "Uplifting and motivational", "Sadness or melancholy", and "Social gatherings or parties". This serves as the dependent variable to analyze whether demographic profiles significantly influence listening motivations.
#
# - Methodological note on the dependent variable
#
#     Because respondents could select multiple motivations, `music_Influencial_mood` is one-hot encoded into four binary columns rather than treated as a single categorical column. As a result, the analysis will consist of **four separate Chi-square tests of independence** — one per motivation, against each demographic variable (Age and Gender) — rather than a single 3×4 contingency test. This preserves the independence-of-observations assumption that an `explode`-based approach would have violated.
#
# - Descriptions of any shortcomings this dataset has with respect to the project
#
#     1. Sampling Bias: The survey respondents are predominantly concentrated in specific age groups (particularly 12–35 years old) and existing Spotify users. Consequently, the sample may not objectively represent the general population.
#     2. Self-reported Data: Since the dataset is based on subjective survey responses, it is susceptible to response bias or inaccuracies stemming from the respondents' personal perceptions and memory regarding their primary motivations.
#     3. Age-related Data Reliability: The dataset contains respondents in the "6–12" age group. However, Spotify's terms of service<a name="back7"> </a>[7](#ref7) generally require users to be 13 or older (users under 13 typically require a Family Plan). This suggests that data for the "6–12" group may reflect shared family usage rather than individual preferences. To ensure data integrity, this specific age group was excluded from the analysis.
#     4. Multiple choice responses: The "music_Influencial_mood" column contained multiple comma-separated responses per user. Initially, we considered using `explode` to unnest these values. However, doing so would create duplicate respondent rows, violating the independence of observations assumption required for Chi-square tests. To maintain this, we instead used One-Hot Encoding. This transformed each unique motivation into its own binary variable (0 or 1) while strictly preserving the assumption.
#
# <a name="ref7"> </a>[^](#back7) Spotify. (2024) Spotify Free and Premium Support: Age requirements. https://www.spotify.com/us/safetyandprivacy/parental-guide

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'data/00-raw/Spotify_user_research.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# 1. Extract 3 columns
df_clean = df[['Age', 'Gender', 'music_Influencial_mood']].copy()

# 2. Exclude '6~12' aged users (under Spotify's minimum age of service)
df_clean = df_clean[df_clean['Age'] != '6~12'].copy()

# 3. Rename and merge age groups
age_group = {
    '12~20': 'Adolescents',
    '20~35': 'Young Adults',
    '35~60': 'Established Adults and Seniors',
    '60+': 'Established Adults and Seniors'
}
df_clean['Age'] = df_clean['Age'].replace(age_group)

# 4. Set Age as an ordered categorical so plots and crosstabs come out in
#    developmental order rather than insertion/alphabetical order.
age_order = ['Adolescents', 'Young Adults', 'Established Adults and Seniors']
df_clean['Age'] = pd.Categorical(df_clean['Age'], categories=age_order, ordered=True)

# 5. One-hot encode the multi-select mood column. We use get_dummies rather
#    than explode to avoid duplicating respondent rows, which would violate
#    the independence-of-observations assumption for Chi-square tests.
mood_dummies = df_clean['music_Influencial_mood'].str.get_dummies(sep=', ')
df_clean = pd.concat([df_clean[['Age', 'Gender']].reset_index(drop=True),
                      mood_dummies.reset_index(drop=True)], axis=1)

# 6. Sanity check: drop any respondents whose mood row is all zeros
#    (i.e., a blank/whitespace original response that produced no dummies).
mood_cols = mood_dummies.columns.tolist()
all_zero = (df_clean[mood_cols].sum(axis=1) == 0)
print(f'Respondents with no mood selected (dropped): {int(all_zero.sum())}')
df_clean = df_clean.loc[~all_zero].reset_index(drop=True)
# Out:
# Respondents with no mood selected (dropped): 0

# %%
print(
    '\nRaw Data\n'
    f"Shape: {df.shape}"
    f"\nthe number of NaN: {df.isna().sum().sum()}"
)
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.show()
# Out:
# Raw Data
# Shape: (28546, 20)
# the number of NaN: 35118

# %%
print(
    '\nCleaned Data\n'
    f"Shape: {df_clean.shape}"
    f"\nColumns: {df_clean.columns.tolist()}"
    f"\nthe number of NaN: {df_clean.isna().sum().sum()}"
    f"\nAge unique: {df_clean['Age'].unique()}"
    f"\nGender unique: {df_clean['Gender'].unique()}"
     )
df_clean.head(10)
# Out:
# Cleaned Data
# Shape: (27543, 6)
# Columns: ['Age', 'Gender', 'Relaxation and stress relief', 'Sadness or melancholy', 'Social gatherings or parties', 'Uplifting and motivational']
# the number of NaN: 0
# Age unique: ['Established Adults and Seniors', 'Young Adults', 'Adolescents']
# Categories (3, str): ['Adolescents' < 'Young Adults' < 'Established Adults and Seniors']
# Gender unique: <StringArray>
# ['Others', 'Male', 'Female']
# Length: 3, dtype: str
#                               Age  Gender  Relaxation and stress relief  \
# 0  Established Adults and Seniors  Others                             0
# 1                    Young Adults    Male                             0
# 2                     Adolescents  Female                             1
# 3                     Adolescents  Female                             0
# 4                     Adolescents    Male                             0
# 5                     Adolescents  Female                             0
# ...

# %%
# Class balance check (Age x Gender) — promised in Ethics C.2.
# Chi-square assumes expected cell counts >= 5; this surfaces any sparse cells.
ct = pd.crosstab(df_clean['Age'], df_clean['Gender'], margins=True, margins_name='Total')
print('Age x Gender counts:')
print(ct)
print()
print('Age x Gender row proportions:')
print(pd.crosstab(df_clean['Age'], df_clean['Gender'], normalize='index').round(3))
# Out:
# Age x Gender counts:
# Gender                          Female   Male  Others  Total
# Age
# Adolescents                       3159   3130    2082   8371
# Young Adults                      4336   4197    2176  10709
# Established Adults and Seniors    3182   3087    2194   8463
# Total                            10677  10414    6452  27543
#
# Age x Gender row proportions:
# Gender                          Female   Male  Others
# Age
# Adolescents                      0.377  0.374   0.249
# Young Adults                     0.405  0.392   0.203
# Established Adults and Seniors   0.376  0.365   0.259

# %%
# import os
# os.makedirs('data/02-processed', exist_ok=True)
# output_path = 'data/02-processed/cleaned_spotify_user_research.csv'
# df_clean.to_csv(output_path, index=False)

# %% [markdown]
# ## Results

# %% [markdown]
# ### Exploratory Data Analysis
#
# Before conducting any statistics tests, we will first perform exploratory data analysis (EDA) to understand any patterns in the data. Since our research topic focuses on whether age groups and gender have any correlation with listening motivations, we will first begin by examining the distribution of respondents of each gender and race. Then we will examine the overall frequency of each listening motivation and the population of each types of audience. Since respondents could select multiple motivations, each motivation was one-hot encoded into a separate binary column. Therefore, the EDA focuses on proportions rather than raw counts when comparing groups, allowing us to compare motivations fairly across age and gender categories of different sizes. Finally, we visualize how the proportion of users selecting each motivation differs across age groups and gender groups.

# %%
df_clean = pd.read_csv('data/02-processed/cleaned_spotify_user_research.csv')

# %% [markdown]
# #### Section 1: Demographic and Motivation Distributions
#
# To understand the baseline characteristics of our dataset, we first visualized the distributions of our independent variables (Age and Gender) and our dependent variables (Primary Listening Motivations).

# %%
sns.set_theme(style="whitegrid", font_scale=1.1)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# --- Age Group Distribution ---
df_clean['Age'].value_counts().sort_values(ascending=False).plot(
    kind='barh', color='#53b67c', edgecolor='none', ax=axes[0], width=0.6
)
axes[0].set_title('Age Group Distribution\n(Excluding 6-12)', pad=15, fontweight='bold')
axes[0].set_xlabel('Users')
axes[0].set_ylabel('AgeGroup')
axes[0].invert_yaxis()

# --- Gender Distribution ---
df_clean['Gender'].value_counts().sort_values(ascending=False).plot(
    kind='barh', color='#e76f51', edgecolor='none', ax=axes[1], width=0.6
)
axes[1].set_title('Gender Distribution', pad=15, fontweight='bold')
axes[1].set_xlabel('Users')
axes[1].set_ylabel('Gender')
axes[1].invert_yaxis()

# --- Primary Motivations for Listening ---
mood_counts = mood_dummies.sum().sort_values(ascending=False)
mood_counts.plot(
    kind='barh', color='#4ba3c3', edgecolor='none', ax=axes[2], width=0.6
)
axes[2].set_title('Primary Motivations for Listening', pad=15, fontweight='bold')
axes[2].set_xlabel('Count')
axes[2].set_ylabel('Motivation')
axes[2].invert_yaxis()

for ax in axes:
    sns.despine(ax=ax, left=False, bottom=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# * **Age Distribution**:
# Young Adults (20–35) form the largest group (\~10,709), while Established Adults and Seniors (\~8,463) and Adolescents (\~8,371) are comparably sized. The sample is moderately skewed toward younger respondents, which is expected given that the data comes from Spotify users. This imbalance means that raw counts alone cannot be used to compare motivations across age groups. Therefore, proportion-based analysis will be essential in the bivariate EDA sections that follow.
#
#
#
# * **Gender Distribution**:
# Female (\~10,677) and Male (\~10,414) respondents are nearly equal in size, while Others (\~6,452) is notably smaller. The Others group represents roughly 23.4% of the sample, which is large enough to include in analysis but warrants careful interpretation given its smaller relative size. The near-parity between Female and Male groups supports a reliable comparison for our hypothesis that adult women show higher association with relaxation than their male counterparts.
#
#
# * **Primary Motivations for Listening**:
# Relaxation and stress relief is the most commonly selected motivation (\~10,568), followed closely by Sadness or melancholy (\~9,886) and Social gatherings or parties (\~8,699). Uplifting and motivational (\~3,793) is selected far less frequently, suggesting it may be a secondary or supplementary motivation for most users. The dominance of Relaxation aligns with our prediction that it would be the primary motivation across most demographic groups. The relative rarity of Uplifting responses is worth monitoring in bivariate analyses, as it may yield less stable Chi-square results.

# %% [markdown]
# #### Summary Statistics

# %%
from modules.analysis import summarize

# --- Summary Tables ---
age_counts = df_clean['Age'].value_counts()
gender_counts = df_clean['Gender'].value_counts()
mood_counts = mood_dummies.sum().sort_values(ascending=False)
n = len(df_clean)

age_summary = summarize(age_counts, n)
gender_summary = summarize(gender_counts, n)
mood_summary = summarize(mood_counts, n)

print('Age Group')
display(age_summary)
print()
print('Gender')
display(gender_summary)
print()
print('Primary Motivations')
display(mood_summary)
# Out:
# Age Group
#                                 Count  Proportion (%)
# Age
# Young Adults                    10709            38.9
# Established Adults and Seniors   8463            30.7
# Adolescents                      8371            30.4
# Gender
#         Count  Proportion (%)
# Gender
# Female  10677            38.8
# Male    10414            37.8
# Others   6452            23.4
# Primary Motivations
#                               Count  Proportion (%)
# Relaxation and stress relief  10568            38.4
# Sadness or melancholy          9886            35.9
# Social gatherings or parties   8699            31.6
# Uplifting and motivational     3793            13.8

# %% [markdown]
# #### Section 2: Age x Mood
#
# Contingency Tables, Data Visualizations, and Statistical Explanations of Age-Related Listening Patterns

# %%
mood_cols = ['Relaxation and stress relief', 'Sadness or melancholy',
             'Social gatherings or parties', 'Uplifting and motivational']

mood_by_age = df_clean.groupby('Age')[mood_cols].mean()

sns.set_theme(style="whitegrid", font_scale=1.1)
fig, axes = plt.subplots(1, len(mood_cols), figsize=(20, 5))

colors = ['#53b67c', '#e76f51', '#4ba3c3', '#f4a261']

for i, mood in enumerate(mood_cols):
    mood_by_age[mood].plot(
        kind='barh', color=colors[i], edgecolor='none', ax=axes[i], width=0.6
    )
    axes[i].set_title(mood, pad=15, fontweight='bold')
    axes[i].set_xlabel('Proportion of Users')
    axes[i].set_ylabel('Age Group')
    axes[i].invert_yaxis()
    axes[i].set_xlim(0, 0.5)
    sns.despine(ax=axes[i], left=False, bottom=False)
axes[i].xaxis.set_tick_params(labelbottom=True)
plt.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(10, 4))

sns.heatmap(
    mood_by_age,
    annot=True, fmt='.2f',
    cmap='YlGnBu',
    linewidths=0.5,
)
plt.title('Proportion of Users per Mood by Age Group', pad=15, fontweight='bold')
plt.xlabel('Listening Motivation', fontsize = 13)
plt.ylabel('Age Group')
plt.tight_layout()
plt.xticks(rotation=0, fontsize=6, fontweight='bold')

plt.show()

# %% [markdown]
# The results show a bar chart and heatmap to clearly express the relationship between age group and listening motivation. The results specifically show the proportion of respondents within each age group who selected each listening motivation. As seen above, Young Adults show the highest proportion for relaxation and stress relief at about 0.41 and uplifting/motivational listening at about 0.18.
#
# Adolescents and Established Adults/Seniors show very similar patterns across most motivations. Both groups selected relaxation and stress relief at about 0.37 and uplifting/motivational listening at about 0.11. Sadness or melancholy also stays almost the same across all age groups at about 0.36, while social gatherings or parties remains very similar at about 0.31–0.32.
#
# The main difference appears in the Young Adults age group. Respondents in this group selected relaxation and stress relief and uplifting/motivational listening at higher rates than the other age groups. This suggests that any overall age association found in the Chi-square test may be driven mostly by differences in these two motivations, rather than by sadness/melancholy or social gathering motivations. Overall, age differences appear strongest for relaxation and uplifting motivations, but not for sadness or social listening.

# %% [markdown]
# ### Section 3: Gender x Mood
#
# Contingency Tables, Data Visualizations, and Statistical Explanations of Gender-Related Listening Patterns, including a Stratified Comparison of Adult Women vs. Adult Men

# %%
mood_cols = ['Relaxation and stress relief', 'Sadness or melancholy',
             'Social gatherings or parties', 'Uplifting and motivational']

mood_by_gender = df_clean.groupby('Gender')[mood_cols].mean()

sns.set_theme(style="whitegrid", font_scale=1.1)
fig, axes = plt.subplots(1, len(mood_cols), figsize=(20, 5))

colors = ['#53b67c', '#e76f51', '#4ba3c3', '#f4a261']

for i, mood in enumerate(mood_cols):
    mood_by_gender[mood].plot(
        kind='barh', color=colors[i], edgecolor='none', ax=axes[i], width=0.6
    )
    axes[i].set_title(mood, pad=15, fontweight='bold')
    axes[i].set_xlabel('Proportion of Users')
    axes[i].set_ylabel('Gender')
    axes[i].invert_yaxis()
    axes[i].set_xlim(0, 0.5)
    sns.despine(ax=axes[i], left=False, bottom=False)
plt.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(12, 3.5))

sns.heatmap(
    mood_by_gender,
    annot=True, fmt='.2f',
    cmap='YlOrRd',
    linewidths=0.5,
    cbar_kws={'shrink': 0.8},
)
plt.title('Proportion of Users per Mood by Gender', pad=15, fontweight='bold')
plt.xlabel('Listening Motivation', fontsize=12)
plt.ylabel('Gender', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# The results show a bar diagram and a heat map to throughly express the data correlation between Gender and their listening motivation.The results specificly gives what proportion of respondents within each gender group select a specific listening motivation. As seen above, Female and Male participents show nearly identical patters accross all moitviations. Both groups selected relaxation and stress relief at about 0.40, sadness or melancholy at about 0.36–0.37, social gatherings or parties at about 0.31, and uplifting/motivational listening at about 0.17–0.18.
#
# The main difference appears in the “Others” gender category. Respondents in this group selected relaxation and sadness at slightly lower rates, social gatherings at a similar or slightly higher rate, and uplifting/motivational listening at a much lower rate of 0.02. This suggests that any overall gender association found in the Chi-square test may be driven more by differences between the “Others” group and the Female/Male groups, rather than by a meaningful difference between Female and Male respondents.

# %% [markdown]
# #### Conditional View: Adult Women vs. Adult Men
#
# Our hypothesis specifically predicts that **adult women (20+)** show a higher association with relaxation than adult men, motivated by Edison Research (2025). The overall Gender x Mood test above takes into account all ages and all gender categories, so it does not directly address the conditional claim. Below, we restrict the sample to **Young Adults and Established Adults/Seniors** and to the **Female and Male** subgroups, then re-run the Chi-square tests.

# %%
adults_fm = df_clean[(df_clean['Age'] != 'Adolescents') &
                     (df_clean['Gender'].isin(['Female', 'Male']))].copy()

mood_by_gender_adults = adults_fm.groupby('Gender')[mood_cols].mean()

sns.set_theme(style="whitegrid", font_scale=1.1)
fig, axes = plt.subplots(1, len(mood_cols), figsize=(20, 5))

colors = ['#53b67c', '#e76f51', '#4ba3c3', '#f4a261']

for i, mood in enumerate(mood_cols):
    mood_by_gender_adults[mood].plot(
        kind='barh', color=colors[i], edgecolor='none', ax=axes[i], width=0.6
    )
    axes[i].set_title(mood, pad=15, fontweight='bold')
    axes[i].set_xlabel('Proportion of Adult Respondents')
    axes[i].set_ylabel('Gender')
    axes[i].invert_yaxis()
    axes[i].set_xlim(0, 0.5)
    sns.despine(ax=axes[i], left=False, bottom=False)

plt.tight_layout()
plt.show()

plt.subplots(figsize=(12, 3.5))

sns.heatmap(
    mood_by_gender_adults,
    annot=True, fmt='.3f',
    cmap='YlOrRd',
    linewidths=0.5,
    cbar_kws={'shrink': 0.8},
)

plt.title('Adult Female vs. Male Motivation Proportions', pad=15, fontweight='bold')
plt.xlabel('Listening Motivation', fontsize=12)
plt.ylabel('Gender', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Adult Female and Male respondents show almost identical listening motivation patterns. Relaxation and stress relief is selected at about 0.401 for Female respondents and 0.399 for Male respondents. Sadness, social gatherings, and uplifting motivations are also very close between the two groups.
#
# Overall, there is no clear visual difference between adult Female and Male respondents. This supports the stratified Chi-square results, which found no statistically significant gender difference for any of the four listening motivations.

# %% [markdown]
# ### Analysis 1: Overall Chi-square Tests of Independence
#
# After using EDA to examine the distribution of age, gender, and listening motivations, we conducted Chi-square tests of independence to formally test whether demographic variables are associated with each music-listening motivation. Since the motivation column was one-hot encoded into separate binary variables, we ran one Chi-square test for each motivation rather than treating the motivations as one single category.
#
# This analysis uses the full cleaned dataset and tests two main relationships: age group versus each listening motivation, and gender versus each listening motivation. The purpose of this analysis is to determine whether music-listening motivations differ across demographic groups at the overall sample level.

# %% [markdown]
# #### Age x Mood
#
# This section compares the proportion of respondents in each age group who selected each listening motivation. The goal is to see whether Adolescents, Young Adults, and Established Adults/Seniors show different patterns before running formal Chi-square tests. Overall, this section helps identify which motivations appear most age-dependent.

# %%
from scipy.stats import chi2_contingency

print("Chi-Square Tests: Age Group vs. Each Listening Motivation\n")
print(f"{'Motivation':<35} {'Chi2':>8} {'p-value':>10} {'Significant?':>14}")
print("-" * 70)

for mood in mood_cols:
    ct = pd.crosstab(df_clean['Age'], df_clean[mood])
    chi2, p, dof, _ = chi2_contingency(ct)
    sig = "Yes ***" if p < 0.001 else ("Yes *" if p < 0.05 else "No")
    print(f"{mood:<35} {chi2:>8.2f} {p:>10.4f} {sig:>14}")
# Out:
# Chi-Square Tests: Age Group vs. Each Listening Motivation
#
# Motivation                              Chi2    p-value   Significant?
# ----------------------------------------------------------------------
# Relaxation and stress relief           35.94     0.0000        Yes ***
# Sadness or melancholy                   1.25     0.5350             No
# Social gatherings or parties            4.85     0.0885             No
# Uplifting and motivational            271.90     0.0000        Yes ***

# %% [markdown]
# ##### Observed Patterns (Proportions by Age Group)
# - Uniformity in "Sadness or melancholy" and Social Motivations: The proportions for "Sadness or melancholy" and "Social gatherings or parties" are consistent across age groups at 36% and 31-32% respectively.
# - Peaks in Young Adults: Young Adults (20-35) show a higher proportion in two categories, "Relaxation and stress relief" (41% vs 37% others) and "Uplifting and motivational" (18% vs 11% others)
#
# **Connection to Research Question**
# - Adolescents (12–20): The hypothesis predicted they would primarily use music for social connection and emotional expression (sadness). While adolescents do use music for these reasons, they do not do so at a higher rate than older adults, contradicting the idea that these motivations are uniquely characteristic of youth.
#
# - Young Adults (20–35): We predicted a transitional focus on relaxation and stress relief. The data strongly supports this. Young adults show the highest proportion of listening for relaxation, aligning with Bonneville-Roussy et al.'s theory that individuals use music heavily for self-regulation as they enter the workforce.
#
# - Established Adults & Seniors (35+): The hypothesis predicted this group would primarily utilize music for relaxation and stress relief based on age-related preferences for positive emotional states. While relaxation is a primary motivation for them (37%), they are surprisingly outpaced by Young Adults (41%). This suggests that while older adults seek comfort in music, the peak need for stress-relief listening actually occurs earlier in adulthood.
#
# **Chi-square Interpretation**
# The Chi-Square test determines if there is a meaningful link between two categorical variables [Age/Gender].
#
# - Statistically Significant (Relaxation & Uplifting): With p-values of 0.0000, there is a clear, mathematical association between a person's age group and their likelihood of listening to music for relaxation or uplifting reasons. If we know a person's age, we have a better statistical guess as to whether they listen for these reasons, especially Young Adults.
#
# - Not Significant (Sadness & Social): With p-values well above the 0.05 threshold (0.5350 and 0.0885), there is no statistical association between age and listening for sadness or social reasons. In this dataset, a person's age has no bearing on whether they listen to music for these purposes.
#
# - Association vs. Causation: It is vital to note that these tests only prove association. Aging itself does not physically cause a person to stop listening to uplifting music; rather, the lifestyle, social, or environmental factors associated with being in a certain age bracket are linked to these listening habits.
#
# **Takeaway.**
# These results support our hypothesis that motivations vary by Age, with the strongest difference appearing in the uplifting and motivational and relaxation and stress relief categories.

# %% [markdown]
# #### Gender × Mood
#
# This section compares the proportion of respondents in each gender group who selected each listening motivation. The goal is to preview whether Female, Male, and Others respondents show different listening patterns. This section is especially important because our hypothesis includes a gender-based prediction about relaxation and stress relief.

# %%
from scipy.stats import chi2_contingency

print("Chi-Square Tests: Gender vs. Each Listening Motivation\n")
print(f"{'Motivation':<35} {'Chi2':>8} {'p-value':>10} {'Significant?':>14}")
print("-" * 70)

for mood in mood_cols:
    ct = pd.crosstab(df_clean['Gender'], df_clean[mood])
    chi2, p, dof, _ = chi2_contingency(ct)
    sig = "Yes ***" if p < 0.001 else ("Yes *" if p < 0.05 else "No")
    print(f"{mood:<35} {chi2:>8.2f} {p:>10.4f} {sig:>14}")
# Out:
# Chi-Square Tests: Gender vs. Each Listening Motivation
#
# Motivation                              Chi2    p-value   Significant?
# ----------------------------------------------------------------------
# Relaxation and stress relief           68.12     0.0000        Yes ***
# Sadness or melancholy                  19.10     0.0001        Yes ***
# Social gatherings or parties            6.18     0.0454          Yes *
# Uplifting and motivational           1042.05     0.0000        Yes ***

# %% [markdown]
# ##### Observed Patterns (Proportions by Gender)
#
# **Overall Gender x Mood (all ages):**
# - After running for which genders show the highest rate of relaxation, sadness, social, and uplifting motivations, we found that Male and Female are essentially identical, according to the heatmap, with the Chi-square significance being driven majority by the Others row. This is especially seen in Uplifting, where Others=0.02 versus Female/Male=0.17-0.18. Additionally, the x^2=1042 on Uplifting is over 10x larger than any other statistic in either table. This suggests that the significant overall finding is truly that Female and Male listeners behave the same, while Others behave differently, rather than the claim that the three gender categories each have their own motivation profile.
#
#
# **Chi-square Interpretation**
#
# - In the overall test, all four motivations showed a significant Gender association (Relaxation χ²=68.12 p<0.001, Sadness χ²=19.10 p=0.0001, Social χ²=6.18 p=0.0454, Uplifting χ²=1042.05 p<0.001).
#
# **Takeaway**
#
# - The overall Gender × Mood results suggest that the "other" gender has a statistically significant difference from male and female. The heatmap shows that female and male respondents have very similar motivation patterns, so the significant chi-square results should be interpreted carefully. The strongest difference appears to come from the “Others” category, especially for uplifting/motivational listening. This means the overall gender association does not necessarily support the idea that female and male respondents differ meaningfully. However, it suggests that the broader gender categories in the dataset may not all follow the same listening motivation patterns.

# %% [markdown]
# ### Analysis 2: Stratified Chi-square Tests for Adult Female vs. Male Respondents
#
# The overall gender analysis includes all age groups and three gender categories: Female, Male, and Others. However, our gender hypothesis specifically predicts that adult women aged 20 and older will show a higher association with relaxation and stress relief than adult men. Because of this, we conducted a stratified analysis focused only on adult respondents in the Young Adults and Established Adults/Seniors age groups, and only on Female and Male respondents.
#
# This second analysis helps test the gender hypothesis more directly. It also allows us to check whether the significant results from the overall Gender × Mood Chi-square tests are actually driven by differences between adult Female and Male respondents, or whether they are mainly influenced by the inclusion of adolescents and the Others gender category.

# %% [markdown]
# #### Conditional View: Adult Women vs. Adult Men
#
# Our hypothesis specifically predicts that **adult women (20+)** show a higher association with relaxation than adult men, motivated by Edison Research (2025). The overall Gender x Mood test above takes into account all ages and all gender categories, so it does not directly address the conditional claim. Below, we restrict the sample to **Young Adults and Established Adults/Seniors** and to the **Female and Male** subgroups, then re-run the Chi-square tests.

# %%
adults_fm = df_clean[(df_clean['Age'] != 'Adolescents') &
                     (df_clean['Gender'].isin(['Female', 'Male']))].copy()

mood_by_gender_adults = adults_fm.groupby('Gender')[mood_cols].mean()
print('Adult-only (20+) proportions by Gender (Female vs Male):')
display(mood_by_gender_adults.round(3))

print("\nChi-Square Tests (Adults only, Female vs Male): Gender vs. Each Motivation\n")
print(f"{'Motivation':<35} {'Chi2':>8} {'p-value':>10} {'Significant?':>14}")
print("-" * 70)

for mood in mood_cols:
    ct = pd.crosstab(adults_fm['Gender'], adults_fm[mood])
    chi2, p, dof, _ = chi2_contingency(ct)
    sig = "Yes ***" if p < 0.001 else ("Yes *" if p < 0.05 else "No")
    print(f"{mood:<35} {chi2:>8.2f} {p:>10.4f} {sig:>14}")
# Out:
# Adult-only (20+) proportions by Gender (Female vs Male):
#         Relaxation and stress relief  Sadness or melancholy  \
# Gender
# Female                         0.401                  0.366
# Male                           0.399                  0.371
#
#         Social gatherings or parties  Uplifting and motivational
# Gender
# Female                         0.308                       0.188
# Male                           0.312                       0.186
# Chi-Square Tests (Adults only, Female vs Male): Gender vs. Each Motivation
#
# Motivation                              Chi2    p-value   Significant?
# ----------------------------------------------------------------------
# Relaxation and stress relief            0.04     0.8361             No
# Sadness or melancholy                   0.47     0.4932             No
# Social gatherings or parties            0.26     0.6133             No
# Uplifting and motivational              0.12     0.7318             No

# %% [markdown]
# **Adults only (Female vs. Male):**
# - All four p-values are between 0.49 and 0.84. Relaxation is 0.401 (F) versus 0.399 (M), with a 0.002 point gap, suggesting that once you remove the Others category and adolescent age bin, there is no detectable difference between Male and Female listeners on motivation.
#
# **Connection to Research Question**
#
# - *Hypothesis:* Women within the adult age bins (20-35 and 35+) will show a statistically higher association with relaxation than their male counterparts (Edison Research, 2025).
# - *Hypothesis verdict: contradicted*
# - Our Edison-Research based prediction was that adult women would show a higher association with Relaxation than adult men, however the data shows no association whatsoever with the p-value sitting at p=0.8361. The small numerical gap (0.002) is in the hypothesized direction but is statistically indistinguishable from zero. Since the p-value far exceeds 0.05, the prediction is not supported by our real data.
#
# **Chi-square Interpretation**
#
# In the adult-only Female-vs-Male test, none remain significant (all four p-values between 0.49 and 0.84). The fact that all motivations switch from significant to insignificant shows us that the overall test was never picking up on Female versus Male signals. It was rather picking up on Others versus Male/Female signals, which disappears once we restrict to the comparison our hypothesis actually called for.
#
#
# **Takeaway**
#
# The data contradicts the Edison-Research derived prediction, as among adult Female and Male respondents there is no real statistically detectable differences on any of the four listening motivations, and the small numerical gap on Relaxation (0.002, in the hypothesized direction) is statistically indistinguishable from zero. This displays a sharp contrast to the Age results in Section 2, where Young Adults peaked clearly on Relaxation (0.41) and Uplifting (0.18), meaning that motivation differences in this dataset track age rather than Female-Male gender. The only gendered effect we can speak on is with the Others category, which by itself is not sufficient to support our original hypothesis.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Since this dataset was likely collected through an online survey, there is a collection bias where respondents are skewed towards those familiar with digital devices.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > The Spotify user survey dataset we are using does not contain Personally Identifiable Information (PII) such as names, email addresses, or specific residential locations.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We will check for extreme imbalances in sample sizes among categories of Age and Gender. If there is a significant class imbalance, the results in statistical tests like ANOVA might be strongly skewed by the larger groups. To avoid confirmation bias, we will adjust our analytical methods as needed so that we do not rely too heavily on specific demographics.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We will pay close attention to the interpretation and description of our analysis results to ensure we do not promote unfair labeling or stereotypes against specific age groups or genders, such as "this age group listens to music solely for emotion X" or "this gender only likes specific genres." We will clearly state that the data only shows general tendencies and does not deny individual diversity.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
#
#
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this
#
#
#
# The goal of the current study was to test the hypothesis that a person's age group and gender determine the type of their main motivation for listening to music. For our analysis, we used a cleaned dataset of Spotify survey responses from 27,543 participants, performing Pearson's Chi-square Tests of Independence for Gender X Motivation and Age Group X Motivation. Our results provided a partial answer to the initial question: While age had a statistically significant effect on motivation in some cases, gender differences in listening motivations disappeared when looking at adult women vs. men.
#
# Age proved to be important, with statistically significant associations found between age group and motivation for Relaxation/Stress Relief (χ² = 35.94, *p* < 0.001) and Uplifting/Motivational Listening (χ² = 271.90, *p* < 0.001). Respondents in the Young Adults (20–35 years old) category reported the highest percentage (about 41%) of motivation for relaxation/stress relief and a high percentage (18%) of uplifting motivation compared to the other ages porportions which were 37% and 11% respectively. Adolescents and Established Adults/Seniors had lower percentages for both motivations. By contrast, Motivation for Sadness or Melancholy and Social Gatherings or Parties failed to reach statistical significance (*p* = 0.535 and *p* = 0.0885, respectively). Therefore, it could be stated that age is related to a person's music listening motivation insofar as it determines why (not necessarily how often) people choose particular motivations.
#
# Our findings about age group somewhat extended existing theories presented in the Background section. Vieillard and Gilet (2013) discussed that older adults tend to favor positive emotion-expressive music, which aligns with our result that uplifting motivation peaks in Young Adults. Bonneville-Roussy et al. (2013) noted that adults tend to self-regulate through music. It is interesting to see that Young Adults are highly engaged in relaxing and uplifting motivations—both self-regulating strategies—in line with the theoretical expectations. One difference in our findings, however, is that older adults do not demonstrate particularly high percentages for relaxation and uplift. Rather, the largest proportion of these motivations comes from the 20–35 age category, which may suggest that entering the workforce and having to deal with adult stress drives more people to seek relaxation and motivation.
#
# The pattern of results for gender appeared confusing at first glance, as Gender × Mood analysis identified statistically significant association of all four motivations, including Social Gatherings/Paties (*p* = 0.0454). Nevertheless, close look at the proportions and heatmaps made it clear the main exception was the “Others” gender category, which differed most noticeably in uplifting/motivational listening. This suggests that the statistically significant overall Gender × Mood results were likely driven more by differences involving the “Others” group than by meaningful differences between Female and Male respondents.
#
# The dramatic uplift in the chi-square statistic for uplifting/motivational listening (χ² = 1042.05) was driven largely by the Others gender category, which reported uplifting listening at roughly 2% compared with about 17–18% for Female and Male respondents. Once we stratified the analysis to adult Female and Male respondents only (ages 20+), none of the four motivations remained significant. Relaxation was 40.1% for women and 39.9% for men—a difference of only 0.2 percentage points with *p* = 0.8361. This directly contradicts our Edison Research (2025)–based hypothesis that adult women would show a higher association with relaxation than adult men.
#
# Taken together, the bigger picture is that demographic effects on music-listening motivation are **selective rather than universal**. Age appears to structure certain functional uses of music—especially self-regulation and motivation—while sadness and social listening seem more stable across age groups in this sample. Gender, at least between adult women and men, does not appear to be a meaningful predictor of listening motivation once the analysis is narrowed to the comparison our hypothesis actually specified. The strongest demographic signal in this dataset is therefore age, not gender.
#
# The contradictory pattern between the overall gender tests (all significant) and the stratified adult Female-vs-Male tests (none significant) is likely a methodological and sampling artifact rather than a true psychological contradiction. Including the Others category—which behaves very differently, especially for uplifting music—inflated chi-square statistics for the three-group comparison. Additionally, the overall test mixed adolescents with adults, blending life stages that may have different motivational profiles. Our one-hot encoding approach also means each respondent could select multiple motivations, so the tests capture association with *selecting* a motivation rather than *ranking* a single primary reason. These design choices are defensible, but they help explain why broad and narrow analyses can tell different stories.
#
# Several limitations constrain how confidently we can generalize. First, the sample is biased toward Spotify users and younger age groups (Young Adults comprise ~39% of respondents), so results may not represent the general population or non-streaming listeners. Second, motivations are self-reported and subject to recall and social-desirability bias. Third, this is cross-sectional survey data: we observe associations at one point in time, not how an individual's motivations evolve as they age. Music psychology research (e.g., Rentfrow & Gosling, 2003; Bonneville-Roussy et al., 2013) suggests listening habits change across the lifespan, so longitudinal tracking would be needed to distinguish true developmental shifts from cohort effects.
#
# Additional studies that go beyond the scope of this course could focus on longitudinal research and tracking the dynamics of how motivation may change throughout one's life; on the distinction of mood from occasions as a variable; on more equal bins for ages; and finally, on stratified analyses where the Others gender will be analyzed separately. More factors can be introduced in order to control the effect and understand better why young adults tend to enjoy so much their relaxed and uplifting music. The use of other platforms for music or replication of the experiment in general could help us determine if this is the general psychological phenomenon, or just platform-specific users' behavior.
#
# In summary, we find that our hypothesis was proved partly. In other words, there is a relationship between the age/gender of the person and music-listening motivations, although not necessarily straightforward. Age significantly predicts relaxation and uplifting motivations of people in a positive way, making young people very engaged in this type of music listening. No significant difference is observed among adult women and men regarding their music-listening motivations on Spotify. The role of demographics in people's music consumption is obvious, but demographics alone are insufficient for explaining all the aspects of why one listens to music.
